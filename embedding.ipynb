# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sentences = [
    'the glass of milk',
    'the glass of juice',
    'the cup of tea',
    'I am a good boy',
    'I am a good developer',
    'understand the meaning of words',
    'we are the learning the nlp'
]

# %%
#define the the vocabulary size
voc_size = 10000

# %%
#one hot representation for every word in the sentences
one_hot_resp = [one_hot(words,voc_size) for words in sentences]
one_hot_resp
# Out:
# [[4395, 88, 7915, 4392],
#  [4395, 88, 7915, 1566],
#  [4395, 6319, 7915, 4060],
#  [4599, 3280, 6215, 1881, 1099],
#  [4599, 3280, 6215, 1881, 4358],
#  [1946, 4395, 6127, 7915, 7452],
#  [4343, 9383, 4395, 1654, 4395, 3264]]

# %%
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.layers import Embedding
from tensorflow.keras.models import Sequential

# %%
max_len = 8

post_padding = pad_sequences(one_hot_resp, maxlen=max_len, padding='post')
pre_padding = pad_sequences(one_hot_resp, maxlen=max_len, padding="pre")

# %%
#feature resprentation of vector
dim = 10

# %%
model = Sequential()
model.add(Embedding(voc_size,dim,input_length = max_len))
model.compile('adam', 'mse')
# Out:
# c:\Users\Devendra\Learning\Project\nlp_venv\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.predict(post_padding)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 376ms/step
# array([[[ 0.04073446, -0.01431851, -0.04452895, -0.03824687,
#          -0.03047913,  0.01339486,  0.02364594, -0.04666084,
#          -0.04660846,  0.02639249],
#         [ 0.00792851, -0.04213481,  0.02407532, -0.0073207 ,
#           0.04322313,  0.0245495 , -0.01913233,  0.02440858,
#          -0.00815241,  0.03164769],
#         [-0.04169804, -0.00358144, -0.02478105,  0.01833219,
#           0.0256379 , -0.00822728,  0.03134913,  0.02458103,
#          -0.03121971, -0.03275328],
#         [-0.01492325,  0.0319204 ,  0.04201717,  0.0145149 ,
#           0.03740871, -0.00748622,  0.02302042,  0.00610473,
#           0.04100564,  0.03926146],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401]],
#
#        [[ 0.04073446, -0.01431851, -0.04452895, -0.03824687,
#          -0.03047913,  0.01339486,  0.02364594, -0.04666084,
#          -0.04660846,  0.02639249],
#         [ 0.00792851, -0.04213481,  0.02407532, -0.0073207 ,
#           0.04322313,  0.0245495 , -0.01913233,  0.02440858,
#          -0.00815241,  0.03164769],
#         [-0.04169804, -0.00358144, -0.02478105,  0.01833219,
#           0.0256379 , -0.00822728,  0.03134913,  0.02458103,
#          -0.03121971, -0.03275328],
#         [ 0.00648197, -0.04827061, -0.03339751, -0.01914229,
#          -0.0063104 ,  0.04021697, -0.03158044,  0.00508021,
#          -0.04435379, -0.04528579],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401]],
#
#        [[ 0.04073446, -0.01431851, -0.04452895, -0.03824687,
#          -0.03047913,  0.01339486,  0.02364594, -0.04666084,
#          -0.04660846,  0.02639249],
#         [-0.02646452, -0.04938547, -0.02717468, -0.01713974,
#          -0.02126025,  0.04254362,  0.01141367,  0.04325796,
#          -0.03329673, -0.0325167 ],
#         [-0.04169804, -0.00358144, -0.02478105,  0.01833219,
#           0.0256379 , -0.00822728,  0.03134913,  0.02458103,
#          -0.03121971, -0.03275328],
#         [-0.01703374, -0.03599115, -0.01582501, -0.04444509,
#           0.02510395,  0.02213233, -0.01744298,  0.02125097,
#          -0.03105798,  0.04214172],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401]],
#
#        [[ 0.00764222, -0.03391147, -0.01446752, -0.03146195,
#           0.00845709, -0.0267583 ,  0.02905306, -0.04970662,
#           0.03846509,  0.04803406],
#         [-0.03972762, -0.02228421,  0.02363252, -0.02379186,
#          -0.0324653 , -0.0084178 ,  0.01760497,  0.02435858,
#          -0.03144486,  0.02066008],
#         [-0.04204509,  0.03089807, -0.0443777 , -0.00616024,
#          -0.011     ,  0.04457143, -0.03951588, -0.01643895,
#          -0.01281816, -0.0377243 ],
#         [ 0.01603461,  0.0160583 , -0.00722443,  0.03963815,
#          -0.01245359, -0.01563163, -0.00051565, -0.02133572,
#           0.03318569,  0.04605669],
#         [-0.04658164, -0.04975144, -0.04861084, -0.03784287,
#           0.04934045,  0.02956624,  0.02682959, -0.04705761,
#           0.00373787,  0.04221084],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401]],
#
#        [[ 0.00764222, -0.03391147, -0.01446752, -0.03146195,
#           0.00845709, -0.0267583 ,  0.02905306, -0.04970662,
#           0.03846509,  0.04803406],
#         [-0.03972762, -0.02228421,  0.02363252, -0.02379186,
#          -0.0324653 , -0.0084178 ,  0.01760497,  0.02435858,
#          -0.03144486,  0.02066008],
#         [-0.04204509,  0.03089807, -0.0443777 , -0.00616024,
#          -0.011     ,  0.04457143, -0.03951588, -0.01643895,
#          -0.01281816, -0.0377243 ],
#         [ 0.01603461,  0.0160583 , -0.00722443,  0.03963815,
#          -0.01245359, -0.01563163, -0.00051565, -0.02133572,
#           0.03318569,  0.04605669],
#         [ 0.00719712,  0.04951413,  0.03438673,  0.02102106,
#           0.02210346,  0.03605263,  0.02938065, -0.02486453,
#          -0.03385144, -0.01476214],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401]],
#
#        [[ 0.02411987, -0.01995702, -0.0068127 , -0.04277824,
#          -0.01044212,  0.03172192,  0.03296019, -0.04855403,
#           0.04619214, -0.04216458],
#         [ 0.04073446, -0.01431851, -0.04452895, -0.03824687,
#          -0.03047913,  0.01339486,  0.02364594, -0.04666084,
#          -0.04660846,  0.02639249],
#         [-0.01022178,  0.03933478,  0.00503846, -0.01032878,
#           0.0416545 , -0.01419478,  0.00365114,  0.04802997,
#           0.02412722, -0.03073542],
#         [-0.04169804, -0.00358144, -0.02478105,  0.01833219,
#           0.0256379 , -0.00822728,  0.03134913,  0.02458103,
#          -0.03121971, -0.03275328],
#         [ 0.02640321, -0.0230737 ,  0.0340315 ,  0.01194954,
#           0.00415671,  0.01373011, -0.02152399, -0.01091855,
#          -0.01390838, -0.00249775],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401]],
#
#        [[ 0.02536971,  0.04960081, -0.02573754,  0.02541423,
#          -0.00813679, -0.03493647,  0.0403252 ,  0.02747515,
#          -0.0421964 , -0.03807293],
#         [ 0.04265077,  0.02037698, -0.01855225,  0.02478638,
#          -0.03202911, -0.01041111, -0.02210544,  0.01682769,
#          -0.02015824,  0.00140093],
#         [ 0.04073446, -0.01431851, -0.04452895, -0.03824687,
#          -0.03047913,  0.01339486,  0.02364594, -0.04666084,
#          -0.04660846,  0.02639249],
#         [-0.02202811,  0.04991538, -0.04854807, -0.00627915,
#           0.01151819, -0.01871477,  0.03323965, -0.04880495,
#          -0.02880504,  0.03883357],
#         [ 0.04073446, -0.01431851, -0.04452895, -0.03824687,
#          -0.03047913,  0.01339486,  0.02364594, -0.04666084,
#          -0.04660846,  0.02639249],
#         [ 0.00137924,  0.01270482, -0.01992474, -0.03058169,
#           0.01024611, -0.04654311, -0.00850253,  0.04487667,
#           0.04440312, -0.00372655],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401],
#         [-0.03154122,  0.01590071, -0.03290366, -0.03792019,
#           0.02324779, -0.0454812 , -0.01999586, -0.02561226,
#          -0.02481914,  0.00548401]]], dtype=float32)
